# %% [markdown]
# <a href="https://colab.research.google.com/github/slayver112/Univercity/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963_%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D0%9E%D0%9E%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6

# %%
# Ваш код
import math
class Sphere:
  def __init__(self, radius, coordx = 0.0, coordy = 0.0, coordz = 0.0):
        self.radius = radius
        self.coordx = coordx
        self.coordy = coordy
        self.coordz = coordz
  def get_volume(self):
    return (4* math.pi * self.radius**3)/3
  def get_square(self):
    return 4*math.pi*(self.radius**2)
  def get_radius(self):
    return self.radius
  def get_center(self):
    return (self.coordx,self.coordy,self.coordz)
  def set_radius(self,radius2):
    self.radius = radius2
  def set_center(self,x,y,z):
    self.coordx = x
    self.coordy = y
    self.coordz = z
  def is_point_inside(self,x1,y1,z1):
    if ((x1-self.coordx)**2 + (y1-self.coordy)**2 + (z1-self.coordz)**2)**0.5<self.radius:
      return True
    else:
      return False
s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235987755982988
# False
# True
# 1.6

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
# Ваш код
class SuperStr(str):
  def is_repeatance(self,s):
    if type(s) is not str:
      return False
    repeat_count = len(self) // len(s)
    if s * repeat_count == self:
      return True
    else:
      return False
  def is_palindrom(self):
    if self == self[::-1]:
      return True
    else:
      return False
s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
# Ваш код
class Student:
  def __init__(self, name, surname, gender, lectures, homeworks):
      self.name = name
      self.surname = surname
      self.gender = gender
      self.finished_courses = []
      self.courses_in_progress = []
      self.grades = {}
      self.attended_lectures = lectures
      self.homeworks = homeworks
  def add_courses(self, course_name):
      self.finished_courses.append(course_name)

class Mentor:
  def __init__(self, name, surname):
      self.name = name
      self.surname = surname
      self.courses_attached = []
  def rate_hw(self, student, course, grade):
      student.grades[course] = [grade]

class Lecturer(Mentor):
  def __init__(self, name, surname, lectures = 0):
    super().__init__(name, surname)
    self.courses_attached = []
    self.attended_lectures = lectures
  def bullying(self, student, course):
    if self.attended_lectures < 3:
      return 'ВЫ НЕ ДОПУЩЕНЫ К ЗАЧЁТУ'
    else:
      return 'У ВАС АВТОМАТ'

class Reviewer(Mentor):
  def __init__(self, name, surname, homeworks):
    super().__init__(name, surname)
    self.courses_attached = []
    self.homeworks = homeworks
  def prank(self, student, course):
    if self.homeworks < 10:
      return 'фу'
    else:
      return 'красавчик'
best_student = Student('Ruoy', 'Eman', 'your_gender', 23, 9)
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)
print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
cool_Lecturer = Lecturer('Andrey','Sotnik', 23)
cool_Reviewer = Reviewer('Stepan','Ludik', 9)
norm_student = Student('Artem', 'Guskov', 'Male', 3, 3)
cool_Lecturer.rate_hw(norm_student, 'IT', 5)
print(cool_Lecturer.bullying(best_student, 'Python'))
print("Оценки студента по курсам: ", norm_student.grades)
print(cool_Reviewer.prank(best_student, 'Python'))
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# У ВАС АВТОМАТ
# Оценки студента по курсам:  {'IT': [5]}
# фу

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Student:
  def __init__(self, name, surname, gender):
      self.name = name
      self.surname = surname
      self.gender = gender
      self.finished_courses = []
      self.courses_in_progress = []
      self.grades = {}

  def add_course_in_progress(self, course_name):
      if course_name not in self.courses_in_progress:
          self.courses_in_progress.append(course_name)

  def add_finished_course(self, course_name):
      if course_name not in self.finished_courses:
          self.finished_courses.append(course_name)

  def rate_lecturer(self, lecturer, course, grade):
      if course in lecturer.grades_for_lectures:
          lecturer.grades_for_lectures[course].append(grade)
      else:
          lecturer.grades_for_lectures[course] = [grade]
      return f"Оценка {grade} успешно поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."

class Mentor:
  def __init__(self, name, surname):
      self.name = name
      self.surname = surname
      self.courses_attached = []

class Lecturer(Mentor):
  def __init__(self, name, surname, attended_lectures_count=0):
    super().__init__(name, surname)
    self.grades_for_lectures = {}
    self.attended_lectures = attended_lectures_count

  def bullying(self, student, course):
    if self.attended_lectures < 3:
      return 'ВЫ НЕ ДОПУЩЕНЫ К ЗАЧЁТУ'
    else:
      return 'У ВАС АВТОМАТ'

class Reviewer(Mentor):
  def __init__(self, name, surname, homeworks_checked_count=0):
    super().__init__(name, surname)
    self.homeworks = homeworks_checked_count

  def rate_hw(self, student, course, grade):
    if course in student.grades:
        student.grades[course].append(grade)
    else:
        student.grades[course] = [grade]
    return f"Оценка {grade} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}."

  def prank(self, student, course):
    if self.homeworks < 10:
      return 'фу'
    else:
      return 'красавчик'

best_student = Student('Ruoy', 'Eman', 'male')
cool_lecturer = Lecturer('Some', 'Lecturer', 10)
cool_reviewer = Reviewer('Some', 'Reviewer', 5)

best_student.add_course_in_progress('Python')
best_student.add_course_in_progress('Git')
cool_lecturer.courses_attached.append('Python')
cool_lecturer.courses_attached.append('Git')
cool_reviewer.courses_attached.append('Python')

print(cool_reviewer.rate_hw(best_student, 'Python', 9))
print(cool_reviewer.rate_hw(best_student, 'Python', 10))
print("Оценки студента по Python:", best_student.grades.get('Python'))

print(best_student.rate_lecturer(cool_lecturer, 'Python', 8))
print(best_student.rate_lecturer(cool_lecturer, 'Python', 7))
print("Оценки лектору по Python:", cool_lecturer.grades_for_lectures.get('Python'))
# Out:
# Оценка 9 успешно поставлена студенту Ruoy Eman за домашнее задание по курсу Python.
# Оценка 10 успешно поставлена студенту Ruoy Eman за домашнее задание по курсу Python.
# Оценки студента по Python: [9, 10]
# Оценка 8 успешно поставлена лектору Some Lecturer за курс Python.
# Оценка 7 успешно поставлена лектору Some Lecturer за курс Python.
# Оценки лектору по Python: [8, 7]

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
class Student:
  def __init__(self, name, surname, gender):
      self.name = name
      self.surname = surname
      self.gender = gender
      self.finished_courses = []
      self.courses_in_progress = []
      self.grades = {}

  def add_course_in_progress(self, course_name):
      if course_name not in self.courses_in_progress:
          self.courses_in_progress.append(course_name)

  def add_finished_course(self, course_name):
      if course_name not in self.finished_courses:
          self.finished_courses.append(course_name)

  def rate_lecturer(self, lecturer, course, grade):
      if course in lecturer.grades_for_lectures:
          lecturer.grades_for_lectures[course].append(grade)
      else:
          lecturer.grades_for_lectures[course] = [grade]
      return f"Оценка {grade} успешно поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."

  def __str__(self):
      avg_grade = 0.0
      if self.grades:
          all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
          if all_grades:
              avg_grade = sum(all_grades) / len(all_grades)

      courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else 'Нет'
      finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else 'Нет'

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за домашние задания: {avg_grade:.1f}\n'\
              f'Курсы в процессе изучения: {courses_in_progress_str}\n'\
              f'Завершенные курсы: {finished_courses_str}')

class Mentor:
  def __init__(self, name, surname):
      self.name = name
      self.surname = surname
      self.courses_attached = []

class Lecturer(Mentor):
  def __init__(self, name, surname, attended_lectures_count=0):
    super().__init__(name, surname)
    self.grades_for_lectures = {}
    self.attended_lectures = attended_lectures_count

  def bullying(self, student, course):
    if self.attended_lectures < 3:
      return 'ВЫ НЕ ДОПУЩЕНЫ К ЗАЧЁТУ'
    else:
      return 'У ВАС АВТОМАТ'

  def __str__(self):
      avg_grade = 0.0
      if self.grades_for_lectures:
          all_grades = [grade for grades_list in self.grades_for_lectures.values() for grade in grades_list]
          if all_grades:
              avg_grade = sum(all_grades) / len(all_grades)

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за лекции: {avg_grade}')

class Reviewer(Mentor):
  def __init__(self, name, surname, homeworks_checked_count=0):
    super().__init__(name, surname)
    self.homeworks = homeworks_checked_count

  def rate_hw(self, student, course, grade):
    if course in student.grades:
        student.grades[course].append(grade)
    else:
        student.grades[course] = [grade]
    return f'Оценка {grade} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}.'

  def prank(self, student, course):
    if self.homeworks < 10:
      return 'фу'
    else:
      return 'красавчик'

  def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

best_student = Student('Ignat', 'Malov', 'Male')
cool_lecturer = Lecturer('Random', 'Lecturer', 10)
cool_reviewer = Reviewer('Random', 'Reviewer', 5)
best_student.add_course_in_progress('Python')
best_student.add_course_in_progress('Git')
best_student.add_finished_course('Введение в программирование')
cool_lecturer.courses_attached.append('Python')
cool_lecturer.courses_attached.append('Git')
cool_reviewer.courses_attached.append('Python')
print(cool_reviewer.rate_hw(best_student, 'Python', 9))
print(cool_reviewer.rate_hw(best_student, 'Python', 10))
print("Оценки студента по Python:", best_student.grades.get('Python'))
print(best_student.rate_lecturer(cool_lecturer, 'Python', 8))
print(best_student.rate_lecturer(cool_lecturer, 'Python', 7))
print("Оценки лектору по Python:", cool_lecturer.grades_for_lectures.get('Python'))
print(cool_reviewer)
print(cool_lecturer)
print(best_student)
# Out:
# Оценка 9 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценка 10 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценки студента по Python: [9, 10]
# Оценка 8 успешно поставлена лектору Random Lecturer за курс Python.
# Оценка 7 успешно поставлена лектору Random Lecturer за курс Python.
# Оценки лектору по Python: [8, 7]
# Имя: Random
# Фамилия: Reviewer
# Имя: Random
# Фамилия: Lecturer
# Средняя оценка за лекции: 7.5
# Имя: Ignat
# Фамилия: Malov
# Средняя оценка за домашние задания: 9.5
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
  def __init__(self, name, surname, gender):
      self.name = name
      self.surname = surname
      self.gender = gender
      self.finished_courses = []
      self.courses_in_progress = []
      self.grades = {}

  def add_course_in_progress(self, course_name):
      if course_name not in self.courses_in_progress:
          self.courses_in_progress.append(course_name)

  def add_finished_course(self, course_name):
      if course_name not in self.finished_courses:
          self.finished_courses.append(course_name)

  def rate_lecturer(self, lecturer, course, grade):
      if course in lecturer.grades_for_lectures:
          lecturer.grades_for_lectures[course].append(grade)
      else:
          lecturer.grades_for_lectures[course] = [grade]
      return f'Оценка {grade} успешно поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}.'

  def __str__(self):
      courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else 'Нет'
      finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else 'Нет'

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Курсы в процессе изучения: {courses_in_progress_str}\n'\
              f'Завершенные курсы: {finished_courses_str}')

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

  def __len__(self):
      return len(self.courses_in_progress) + len(self.finished_courses)

class Mentor:
  def __init__(self, name, surname):
      self.name = name
      self.surname = surname
      self.courses_attached = []

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

  def __len__(self):
      return len(self.courses_attached)


class Lecturer(Mentor):
  def __init__(self, name, surname, attended_lectures_count=0):
    super().__init__(name, surname)
    self.grades_for_lectures = {}
    self.attended_lectures = attended_lectures_count

  def bullying(self, student, course):
    if self.attended_lectures < 3:
      return 'ВЫ НЕ ДОПУЩЕНЫ К ЗАЧЁТУ'
    else:
      return 'У ВАС АВТОМАТ'

  def __str__(self):
      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n')

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

class Reviewer(Mentor):
  def __init__(self, name, surname, homeworks_checked_count=0):
    super().__init__(name, surname)
    self.homeworks = homeworks_checked_count
  def rate_hw(self, student, course, grade):
    if course in student.grades:
        student.grades[course].append(grade)
    else:
        student.grades[course] = [grade]
    return f'Оценка {grade} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}.'

  def prank(self, student, course):
    if self.homeworks < 10:
      return 'фу'
    else:
      return 'красавчик'

  def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'


best_student = Student('Ignat', 'Malov', 'Male')
cool_lecturer = Lecturer('Random', 'Lecturer', 10)
cool_reviewer = Reviewer('Random', 'Reviewer', 5)
poorer_student = Student('Artem', 'Guskov', 'Male')
well_graded_lecturer = Lecturer('Alexander', 'Streltsov')
well_graded_reviewer = Reviewer('Evegeniy', 'Lebedev')
best_student.add_course_in_progress('Python')
best_student.add_course_in_progress('Git')
best_student.add_finished_course('Введение в программирование')
poorer_student.add_course_in_progress('Java')
cool_lecturer.courses_attached.append('Python')
cool_lecturer.courses_attached.append('Git')
well_graded_lecturer.courses_attached.append('Python')
cool_reviewer.courses_attached.append('Python')
well_graded_reviewer.courses_attached.append('Python')
well_graded_reviewer.courses_attached.append('IT')

print(cool_reviewer.rate_hw(best_student, 'Python', 9))
print(cool_reviewer.rate_hw(best_student, 'Python', 10))
print(cool_reviewer.rate_hw(poorer_student, 'Python', 5))
print("Оценки студента по Python:", best_student.grades.get('Python'))
print("Оценки Гуськова по Python:", poorer_student.grades.get('Python'))

print(best_student.rate_lecturer(cool_lecturer, 'Python', 8))
print(best_student.rate_lecturer(cool_lecturer, 'Python', 7))
print(best_student.rate_lecturer(well_graded_lecturer, 'Python', 10))
print(best_student.rate_lecturer(well_graded_lecturer, 'IT', 9))
print('Оценки лектору по Python:', cool_lecturer.grades_for_lectures.get('Python'))
print('Оценки Alexander Streltsov по Python:', well_graded_lecturer.grades_for_lectures.get('Python'))

print(cool_reviewer)
print(cool_lecturer)
print(best_student+poorer_student)
print(best_student)
# Out:
# Оценка 9 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценка 10 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценка 5 успешно поставлена студенту Artem Guskov за домашнее задание по курсу Python.
# Оценки студента по Python: [9, 10]
# Оценки Гуськова по Python: [5]
# Оценка 8 успешно поставлена лектору Random Lecturer за курс Python.
# Оценка 7 успешно поставлена лектору Random Lecturer за курс Python.
# Оценка 10 успешно поставлена лектору Alexander Streltsov за курс Python.
# Оценка 9 успешно поставлена лектору Alexander Streltsov за курс IT.
# Оценки лектору по Python: [8, 7]
# Оценки Alexander Streltsov по Python: [10]
# Имя: Random
# Фамилия: Reviewer
# Имя: Random
# Фамилия: Lecturer
#
# 247
# Имя: Ignat
# Фамилия: Malov
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
  def __init__(self, name, surname, gender):
      self.name = name
      self.surname = surname
      self.gender = gender
      self.finished_courses = []
      self.courses_in_progress = []
      self.grades = {}

  def add_course_in_progress(self, course_name):
      if course_name not in self.courses_in_progress:
          self.courses_in_progress.append(course_name)

  def add_finished_course(self, course_name):
      if course_name not in self.finished_courses:
          self.finished_courses.append(course_name)

  def _get_average_grade(self):
      if not self.grades:
          return 0.0
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades) / len(all_grades) if all_grades else 0.0

  def rate_lecturer(self, lecturer, course, grade):
      if course in lecturer.grades_for_lectures:
          lecturer.grades_for_lectures[course].append(grade)
      else:
          lecturer.grades_for_lectures[course] = [grade]
      return f'Оценка {grade} успешно поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}.'

  def __str__(self):
      avg_grade = self._get_average_grade()
      courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else 'Нет'
      finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else 'Нет'

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за домашние задания: {avg_grade:.1f}\n'\
              f'Курсы в процессе изучения: {courses_in_progress_str}\n'\
              f'Завершенные курсы: {finished_courses_str}')

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

  def __len__(self):
      return len(self.courses_in_progress) + len(self.finished_courses)

class Mentor:
  def __init__(self, name, surname):
      self.name = name
      self.surname = surname
      self.courses_attached = []

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

  def __len__(self):
      return len(self.courses_attached)


class Lecturer(Mentor):
  def __init__(self, name, surname, attended_lectures_count=0):
    super().__init__(name, surname)
    self.grades_for_lectures = {}
    self.attended_lectures = attended_lectures_count

  def _get_average_lecture_grade(self):
      all_grades = [grade for grades_list in self.grades_for_lectures.values() for grade in grades_list]
      return sum(all_grades) / len(all_grades) if all_grades else 0.0

  def bullying(self, student, course):
    if self.attended_lectures < 3:
      return 'ВЫ НЕ ДОПУЩЕНЫ К ЗАЧЁТУ'
    else:
      return 'У ВАС АВТОМАТ'

  def __str__(self):
      avg_grade = self._get_average_lecture_grade()
      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за лекции: {avg_grade}')

  def __add__(self, other):
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades)+228

class Reviewer(Mentor):
  def __init__(self, name, surname, homeworks_checked_count=0):
    super().__init__(name, surname)
    self.homeworks = homeworks_checked_count
  def rate_hw(self, student, course, grade):
    if course in student.grades:
        student.grades[course].append(grade)
    else:
        student.grades[course] = [grade]
    return f'Оценка {grade} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}.'

  def prank(self, student, course):
    if self.homeworks < 10:
      return 'фу'
    else:
      return 'красавчик'

  def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'


best_student = Student('Ignat', 'Malov', 'Male')
cool_lecturer = Lecturer('Random', 'Lecturer', 10)
cool_reviewer = Reviewer('Random', 'Reviewer', 5)
poorer_student = Student('Artem', 'Guskov', 'Male')
well_graded_lecturer = Lecturer('Alexander', 'Streltsov')
well_graded_reviewer = Reviewer('Evegeniy', 'Lebedev')
best_student.add_course_in_progress('Python')
best_student.add_course_in_progress('Git')
best_student.add_finished_course('Введение в программирование')
poorer_student.add_course_in_progress('Java')
cool_lecturer.courses_attached.append('Python')
cool_lecturer.courses_attached.append('Git')
well_graded_lecturer.courses_attached.append('Python')
cool_reviewer.courses_attached.append('Python')
well_graded_reviewer.courses_attached.append('Python')
well_graded_reviewer.courses_attached.append('IT')

print(cool_reviewer.rate_hw(best_student, 'Python', 9))
print(cool_reviewer.rate_hw(best_student, 'Python', 10))
print(cool_reviewer.rate_hw(poorer_student, 'Python', 5))
print("Оценки студента по Python:", best_student.grades.get('Python'))
print("Оценки Гуськова по Python:", poorer_student.grades.get('Python'))

print(best_student.rate_lecturer(cool_lecturer, 'Python', 8))
print(best_student.rate_lecturer(cool_lecturer, 'Python', 7))
print(best_student.rate_lecturer(well_graded_lecturer, 'Python', 10))
print(best_student.rate_lecturer(well_graded_lecturer, 'IT', 9))
print('Оценки лектору по Python:', cool_lecturer.grades_for_lectures.get('Python'))
print('Оценки Alexander Streltsov по Python:', well_graded_lecturer.grades_for_lectures.get('Python'))

print(cool_reviewer)
print(cool_lecturer)
print(best_student+poorer_student)
print(best_student)
# Out:
# Оценка 9 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценка 10 успешно поставлена студенту Ignat Malov за домашнее задание по курсу Python.
# Оценка 5 успешно поставлена студенту Artem Guskov за домашнее задание по курсу Python.
# Оценки студента по Python: [9, 10]
# Оценки Гуськова по Python: [5]
# Оценка 8 успешно поставлена лектору Random Lecturer за курс Python.
# Оценка 7 успешно поставлена лектору Random Lecturer за курс Python.
# Оценка 10 успешно поставлена лектору Alexander Streltsov за курс Python.
# Оценка 9 успешно поставлена лектору Alexander Streltsov за курс IT.
# Оценки лектору по Python: [8, 7]
# Оценки Alexander Streltsov по Python: [10]
# Имя: Random
# Фамилия: Reviewer
# Имя: Random
# Фамилия: Lecturer
# Средняя оценка за лекции: 7.5
# 247
# Имя: Ignat
# Фамилия: Malov
# Средняя оценка за домашние задания: 9.5
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
import math


class Fraction:
    def __init__(self, numerator, denominator=1):
        if denominator == 0:
            raise ValueError('Знаменатель не может быть нулем')
        self._simplify(numerator, denominator)

    def _simplify(self, numerator, denominator):
        if denominator < 0:
            numerator = -numerator
            denominator = -denominator
        gcd_value = math.gcd(abs(numerator), denominator)
        self.numerator = numerator // gcd_value
        self.denominator = denominator // gcd_value

    def __add__(self, other):
        if isinstance(other, Fraction):
            new_numerator = (self.numerator * other.denominator + other.numerator * self.denominator)
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        elif isinstance(other, (int, float)):
            return self + Fraction.from_float(other)
        else:
            return NotImplemented

    def __radd__(self, other):
        return self + other

    def __sub__(self, other):
        if isinstance(other, Fraction):
            new_numerator = (self.numerator * other.denominator -
                           other.numerator * self.denominator)
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        elif isinstance(other, (int, float)):
            return self - Fraction.from_float(other)
        else:
            return NotImplemented

    def __rsub__(self, other):
        if isinstance(other, (int, float)):
            return Fraction.from_float(other) - self
        else:
            return NotImplemented

    def __mul__(self, other):
        if isinstance(other, Fraction):
            new_numerator = self.numerator * other.numerator
            new_denominator = self.denominator * other.denominator
            return Fraction(new_numerator, new_denominator)
        elif isinstance(other, (int, float)):
            return self * Fraction.from_float(other)
        else:
            return NotImplemented

    def __rmul__(self, other):
        return self * other

    def __truediv__(self, other):
        if isinstance(other, Fraction):
            if other.numerator == 0:
                raise ZeroDivisionError('Деление на нулевую дробь')
            new_numerator = self.numerator * other.denominator
            new_denominator = self.denominator * other.numerator
            return Fraction(new_numerator, new_denominator)
        elif isinstance(other, (int, float)):
            if other == 0:
                raise ZeroDivisionError('Деление на ноль')
            return self / Fraction.from_float(other)
        else:
            return NotImplemented

    def __rtruediv__(self, other):
        if isinstance(other, (int, float)):
            return Fraction.from_float(other) / self
        else:
            return NotImplemented

    def __eq__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator == other.numerator and
                   self.denominator == other.denominator)
        elif isinstance(other, (int, float)):
            return float(self) == other
        else:
            return NotImplemented

    def __lt__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator <
                   other.numerator * self.denominator)
        elif isinstance(other, (int, float)):
            return float(self) < other
        else:
            return NotImplemented

    def __le__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator <=
                   other.numerator * self.denominator)
        elif isinstance(other, (int, float)):
            return float(self) <= other
        else:
            return NotImplemented

    def __gt__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator >
                   other.numerator * self.denominator)
        elif isinstance(other, (int, float)):
            return float(self) > other
        else:
            return NotImplemented

    def __ge__(self, other):
        if isinstance(other, Fraction):
            return (self.numerator * other.denominator >=
                   other.numerator * self.denominator)
        elif isinstance(other, (int, float)):
            return float(self) >= other
        else:
            return NotImplemented

    def __neg__(self):
        return Fraction(-self.numerator, self.denominator)

    def __float__(self):
        return self.numerator / self.denominator

    def reciprocal(self):
        if self.numerator == 0:
            raise ZeroDivisionError('Нельзя получить обратную дробь для нуля')
        return Fraction(self.denominator, self.numerator)

    def __str__(self):
        if self.denominator == 1:
            return str(self.numerator)
        return f"{self.numerator}/{self.denominator}"

    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"

    @classmethod
    def from_float(cls, value):
        if isinstance(value, int):
            return cls(value, 1)
        str_value = str(value)
        if 'e' in str_value:
            base, exp = str_value.split('e')
            decimal_places = len(base.split('.')[1]) if '.' in base else 0
            exp = int(exp)
            numerator = int(float(base) * (10 ** (decimal_places - exp)))
            denominator = 10 ** decimal_places
        else:
            decimal_places = len(str_value.split('.')[1])
            numerator = int(value * (10 ** decimal_places))
            denominator = 10 ** decimal_places
        return cls(numerator, denominator)
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# 19/12
# -1/12
# 5/8
# 9/10
# True
# False
# True
# 0.75
# 4/3
# 3/4
# Знаменатель не может быть нулем
# 3/4
# Fraction(3, 4)

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
